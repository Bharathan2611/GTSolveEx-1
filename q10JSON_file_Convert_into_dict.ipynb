# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharathan2611/GTSolveEx-1/blob/main/q10JSON_file_Convert_into_dict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10.Write a function to read a JSON file and convert to dict.

# %%
"""
step 1: Create a function
step 2: Check file is valid or not then raise ValueError
step 3: Read JSON file convert to dict json module
step 4: Return dict data
"""
# Out:
# '\nstep 1: Create a function\nstep 2: Check file is valid or not then raise ValueError\nstep 3: Read JSON file convert to dict json module\nstep 4: Return dict data\n'

# %%
import json
#Step 1: Create a function
def json_to_dict(file_path):
    #Step 2: Check file is valid or not then raise ValueError
    try:
        with open(file_path, 'r') as file:
            #Step 3: Read JSON file convert to dict json module
            data = json.load(file)
            #Step 4: Return dict data
            return data
    except FileNotFoundError:
        raise ValueError("File not found")
    except json.JSONDecodeError:
        raise ValueError("Invalid JSON format")

# %%
# Example usage
dict_data = json_to_dict('data.json')
print(dict_data)
# Out:
# [{'id': 1, 'name': 'Bharathan', 'amount': 200, 'status': 'processed'}, {'id': 2, 'name': 'Vijayalakshmi', 'amount': 500, 'status': 'processed'}]

# %%
dict_data = json_to_dict('invalid.json')  #File not found
print(dict_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9680/3764434950.py in json_to_dict(file_path)
#       5     try:
# ----> 6         with open(file_path, 'r') as file:
#       7             #Step 3: Read JSON file convert to dict json module
#
# FileNotFoundError: [Errno 2] No such file or directory: 'invalid.json'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9680/4116928691.py in <cell line: 0>()
# ----> 1 dict_data = json_to_dict('invalid.json')  #File not found
#       2 print(dict_data)
#       3
#
# /tmp/ipykernel_9680/3764434950.py in json_to_dict(file_path)
#      10             return data
#      11     except FileNotFoundError:
# ---> 12         raise ValueError("File not found")
#      13     except json.JSONDecodeError:
#      14         raise ValueError("Invalid JSON format")
#
# ValueError: File not found

# %%
dict_data = json_to_dict('GT solve Overall About Company.txt') #Invalid JSON format
print(dict_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9680/3764434950.py in json_to_dict(file_path)
#       5     try:
# ----> 6         with open(file_path, 'r') as file:
#       7             #Step 3: Read JSON file convert to dict json module
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GT solve Overall About Company.txt'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9680/710536962.py in <cell line: 0>()
# ----> 1 dict_data = json_to_dict('GT solve Overall About Company.txt') #Invalid JSON format
#       2 print(dict_data)
#
# /tmp/ipykernel_9680/3764434950.py in json_to_dict(file_path)
#      10             return data
#      11     except FileNotFoundError:
# ---> 12         raise ValueError("File not found")
#      13     except json.JSONDecodeError:
#      14         raise ValueError("Invalid JSON format")
#
# ValueError: File not found
