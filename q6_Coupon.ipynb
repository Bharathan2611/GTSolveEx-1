# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharathan2611/GTSolveEx-1/blob/main/q6_Coupon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 6.	Create a function to
#     generate the same coupon code for all users using map and lambda functions.
#
# Sample Input:
# [
# {user:”alice”,coupon:””},
# {user:”BOB”,coupon:””}
# ]
# Sample Output:
#
# [
# {user:”alice”,coupon:”NEWUSER”},
# {user:”BOB”,coupon:”NEWUSER”}
# ]

# %%
"""
Step 1: Create a func
Step 2: list of user name and Coupon code
Step 3: Create lambda dunc to generate cooupon code for all user
"""
# Out:
# '\nStep 1: Create a func\nStep 2: list of user name and Coupon code\nStep 3: Create lambda dunc to generate cooupon code for all user\n'

# %%
#Step 1: Create a func
def gen_coupon(users):
    #Step 2: list of user name and Coupon code
    if type(users)!=list:
        raise ValueError("Invalid input data")

    for u in users:
        if "user" not in u:
            raise ValueError("Invalid user data:", u)

    #Step 3: Create lambda dunc to generate cooupon code for all user
    generate_coupon = lambda customerName: {"user": customerName["user"], "coupon": "NEWUSER"}
    return list(map(generate_coupon, users))

# %%
input=[
    {"user": "Suganya", "coupon": ""},
    {"user": "Bharathan", "coupon": ""},
    {"user": "Vijayalakshmi", "coupon": ""},
    {"user": "Durai", "coupon": ""}
]

print(gen_coupon(input))
# Out:
# [{'user': 'Suganya', 'coupon': 'NEWUSER'}, {'user': 'Bharathan', 'coupon': 'NEWUSER'}, {'user': 'Vijayalakshmi', 'coupon': 'NEWUSER'}, {'user': 'Durai', 'coupon': 'NEWUSER'}]

# %%
input=[
    {"user": "Suganya", "coupon": ""},
    {"user": "Gowtham"},
    {"coupon": ""}
]

print(gen_coupon(input))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_503/3704686947.py in <cell line: 0>()
#       5 ]
#       6
# ----> 7 print(gen_coupon(input))
#
# /tmp/ipykernel_503/2275399581.py in gen_coupon(users)
#       7     for u in users:
#       8         if "user" not in u:
# ----> 9             raise ValueError("Invalid user data:", u)
#      10
#      11     #Step 3: Create lambda dunc to generate cooupon code for all user
#
# ValueError: ('Invalid user data:', {'coupon': ''})
